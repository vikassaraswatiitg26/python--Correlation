# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize']=(12,8)   # Adjust the configuration of plot we create

# %%
df= pd.read_csv(r"C:\Users\VIKAS\Desktop\pandas dataset\movies.csv")

# %%
df.head(5)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
for col in df.columns:
 pct_missing=np.mean(df[col].isnull())
 print('{}-{:.2f}%'.format(col,pct_missing))
# Out:
# name-0.00%
# rating-0.01%
# genre-0.00%
# year-0.00%
# released-0.00%
# score-0.00%
# votes-0.00%
# director-0.00%
# writer-0.00%
# star-0.00%
# country-0.00%
# budget-0.28%
# gross-0.02%
# company-0.00%
# runtime-0.00%

# %%
df.dropna(inplace=True)

# %%
for col1 in df.columns:
 pct_missing1=np.mean(df[col1].isnull())
 print('{}-{:.2f}%'.format(col1,pct_missing1))
# Out:
# name-0.00%
# rating-0.00%
# genre-0.00%
# year-0.00%
# released-0.00%
# score-0.00%
# votes-0.00%
# director-0.00%
# writer-0.00%
# star-0.00%
# country-0.00%
# budget-0.00%
# gross-0.00%
# company-0.00%
# runtime-0.00%

# %%
df.head(5)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df=df.reset_index(drop=True)

# %%
# type of data 
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# change the datatype ofthe column

df['budget']=df['budget'].astype("int64")

df['gross']=df['gross'].astype("int64")

# %%
df.head(5)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
df["released"]=df["released"].str.replace(r'\s*\(.*?\)','',regex=True)

# %%
df.head(5)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#         released  score      votes         director                   writer  \
# 0  June 13, 1980    8.4   927000.0  Stanley Kubrick             Stephen King
# 1   July 2, 1980    5.8    65000.0   Randal Kleiser  Henry De Vere Stacpoole
# 2  June 20, 1980    8.7  1200000.0   Irvin Kershner           Leigh Brackett
# 3   July 2, 1980    7.7   221000.0     Jim Abrahams             Jim Abrahams
# 4  July 25, 1980    7.3   108000.0     Harold Ramis       Brian Doyle-Murray
#
# ...

# %%
df['released'] = pd.to_datetime(df['released'], format='mixed', errors='coerce')     # this format is used because in released date columnin cases the cfromate is misplaces or there some error


#df['released']=pd.to_datetime(df['released'])

# %%
df['released']=df['released'].dt.strftime('%Y-%m-%d')

# %%
df.head(25)
# Out:
#                                               name rating      genre  year  \
# 0                                      The Shining      R      Drama  1980
# 1                                  The Blue Lagoon      R  Adventure  1980
# 2   Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                        Airplane!     PG     Comedy  1980
# 4                                       Caddyshack      R     Comedy  1980
# 5                                  Friday the 13th      R     Horror  1980
# 6                               The Blues Brothers      R     Action  1980
# 7                                      Raging Bull      R  Biography  1980
# 8                                      Superman II     PG     Action  1980
# 9                                  The Long Riders      R  Biography  1980
# 10                           Any Which Way You Can     PG     Action  1980
# ...

# %%
df['yearcorrect']=df['released'].astype(str).str[0:4]

# %%
df.head(25)
# Out:
#                                               name rating      genre  year  \
# 0                                      The Shining      R      Drama  1980
# 1                                  The Blue Lagoon      R  Adventure  1980
# 2   Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                        Airplane!     PG     Comedy  1980
# 4                                       Caddyshack      R     Comedy  1980
# 5                                  Friday the 13th      R     Horror  1980
# 6                               The Blues Brothers      R     Action  1980
# 7                                      Raging Bull      R  Biography  1980
# 8                                      Superman II     PG     Action  1980
# 9                                  The Long Riders      R  Biography  1980
# 10                           Any Which Way You Can     PG     Action  1980
# ...

# %%
df2=df.sort_values(by="gross",inplace=False,ascending=False)

# %%
df2.head(5)
# Out:
#                                             name rating   genre  year  \
# 3731                                      Avatar  PG-13  Action  2009
# 5302                           Avengers: Endgame  PG-13  Action  2019
# 1795                                     Titanic  PG-13   Drama  1997
# 4730  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 5158                      Avengers: Infinity War  PG-13  Action  2018
#
#         released  score      votes       director              writer  \
# 3731  2009-12-18    7.8  1100000.0  James Cameron       James Cameron
# 5302  2019-04-26    8.4   903000.0  Anthony Russo  Christopher Markus
# 1795  1997-12-19    7.8  1100000.0  James Cameron       James Cameron
# 4730  2015-12-18    7.8   876000.0    J.J. Abrams     Lawrence Kasdan
# 5158  2018-04-27    8.4   897000.0  Anthony Russo  Christopher Markus
#
#                    star        country     budget       gross  \
# ...

# %%
pd.reset_option('display.max_rows')

# %%
# Drop any duplicates
df.drop_duplicates()
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 5416                               Bad Boys for Life          R     Action
# 5417                              Sonic the Hedgehog         PG     Action
# 5418                                        Dolittle         PG  Adventure
# 5419                            The Call of the Wild         PG  Adventure
# 5420                               The Eight Hundred  Not Rated     Action
#
#       year   released  score      votes         director  \
# ...

# %%
df['company'].drop_duplicates().sort_values(ascending=False)
# Out:
# 5101                                thefyzz
# 3920                            micro_scope
# 2551                               i5 Films
# 4834                             i am OTHER
# 4537                                   erbp
#                        ...
# 216                        1818 Productions
# 1727                          1492 Pictures
# 1785                        .406 Production
# 5375    "Weathering With You" Film Partners
# 2850        "DIA" Productions GmbH & Co. KG
# Name: company, Length: 1475, dtype: object

# %%
for col in df.columns:
    pct_missing=np.mean(df[col].isna())
    print('{}-{:.2f}%'.format(col,pct_missing))
# Out:
# name-0.00%
# rating-0.00%
# genre-0.00%
# year-0.00%
# released-0.00%
# score-0.00%
# votes-0.00%
# director-0.00%
# writer-0.00%
# star-0.00%
# country-0.00%
# budget-0.00%
# gross-0.00%
# company-0.00%
# runtime-0.00%
# yearcorrect-0.00%

# %%
df.dropna(inplace=True)

# %%
for col in df.columns:
    pct_missing=np.mean(df[col].isna())
    print('{}-{:.2f}%'.format(col,pct_missing))
# Out:
# name-0.00%
# rating-0.00%
# genre-0.00%
# year-0.00%
# released-0.00%
# score-0.00%
# votes-0.00%
# director-0.00%
# writer-0.00%
# star-0.00%
# country-0.00%
# budget-0.00%
# gross-0.00%
# company-0.00%
# runtime-0.00%
# yearcorrect-0.00%

# %%
df["company"].drop_duplicates().sort_values(ascending=False)
# Out:
# 5101                                thefyzz
# 3920                            micro_scope
# 2551                               i5 Films
# 4834                             i am OTHER
# 4537                                   erbp
#                        ...
# 216                        1818 Productions
# 1727                          1492 Pictures
# 1785                        .406 Production
# 5375    "Weathering With You" Film Partners
# 2850        "DIA" Productions GmbH & Co. KG
# Name: company, Length: 1475, dtype: object

# %%
# Budget high correlation
# Company high correlation


# Scatter plot with bidget vs gross

plt.scatter(x=df['budget'],y=df['gross'])
plt.title("Budget vs gross Earnings")
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')

plt.show()

# %%
# Plot budget vs gross using seaborn


sns.regplot(x='budget',y='gross',data=df,scatter_kws={"color":"red"},line_kws={"color":"blue"})
plt.xlabel("Gross earning")
plt.ylabel("Budget")
plt.title("Budget v/s gross Earnings")
# Out:
# Text(0.5, 1.0, 'Budget v/s gross Earnings')

# %% [markdown]
# # lets's start Looking at correlation
#
# different methos of correlation are  # pearson ,kendall,spearman

# %%
df.select_dtypes(include="number").corr('pearson')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
# High Correlation between budget and gross
# I was right

# %%
correlation_matrix=df.select_dtypes(include="number").corr("pearson")

sns.heatmap(correlation_matrix,annot=True)          # annot=True Display the numerical values (annotations) inside each cell of the heatmap
plt.title("correlation Matrix for Numeric Features ")

plt.show()

# %%
# looks at Company 

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#      released  score      votes         director                   writer  \
# 0  1980-06-13    8.4   927000.0  Stanley Kubrick             Stephen King
# 1  1980-07-02    5.8    65000.0   Randal Kleiser  Henry De Vere Stacpoole
# 2  1980-06-20    8.7  1200000.0   Irvin Kershner           Leigh Brackett
# 3  1980-07-02    7.7   221000.0     Jim Abrahams             Jim Abrahams
# 4  1980-07-25    7.3   108000.0     Harold Ramis       Brian Doyle-Murray
#
# ...

# %%
df_numerized=df.copy()

for col_name in df_numerized.columns:                                          # this has converted the non-numeric data to a numeric data for the columns which are object
    if(df_numerized[col_name].dtype=='object'):
       df_numerized[col_name]=df_numerized[col_name].astype('category')             
       df_numerized[col_name]=df_numerized[col_name].cat.codes

df_numerized.head(25)
# Out:
#     name  rating  genre  year  released  score      votes  director  writer  \
# 0   4692       6      6  1980         8    8.4   927000.0      1795    2832
# 1   3929       6      1  1980        12    5.8    65000.0      1578    1158
# 2   3641       4      0  1980         9    8.7  1200000.0       757    1818
# 3    204       4      4  1980        12    7.7   221000.0       889    1413
# 4    732       6      4  1980        14    7.3   108000.0       719     351
# 5   1509       6      9  1980         4    6.4   123000.0      1758    3081
# 6   3930       6      0  1980         9    7.9   188000.0       974     576
# 7   3122       6      3  1980        26    8.2   330000.0      1269    1257
# 8   3732       4      0  1980        39    6.8   101000.0      1606    1402
# 9   4401       6      3  1980         5    7.0    10000.0      2011     280
# 10   332       4      0  1980        25    6.1    18000.0       236    2810
# ...

# %%
df.head(5)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#     released  score      votes         director                   writer  \
# 0 1980-06-13    8.4   927000.0  Stanley Kubrick             Stephen King
# 1 1980-07-02    5.8    65000.0   Randal Kleiser  Henry De Vere Stacpoole
# 2 1980-06-20    8.7  1200000.0   Irvin Kershner           Leigh Brackett
# 3 1980-07-02    7.7   221000.0     Jim Abrahams             Jim Abrahams
# 4 1980-07-25    7.3   108000.0     Harold Ramis       Brian Doyle-Murray
#
#              star         country    budget      gross             company  \
# ...

# %%
correlation_matrix=df_numerized.corr(method='pearson')

sns.heatmap(correlation_matrix,annot=True)
plt.title('Correlation Matric for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
df_numerized.corr()
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.029234  0.010996  0.025542  0.026964  0.014450
# rating      -0.029234  1.000000  0.147796  0.019499  0.020140  0.065983
# genre        0.010996  0.147796  1.000000 -0.073167 -0.069923  0.035106
# year         0.025542  0.019499 -0.073167  1.000000  0.997618  0.056386
# released     0.026964  0.020140 -0.069923  0.997618  1.000000  0.065076
# score        0.014450  0.065983  0.035106  0.056386  0.065076  1.000000
# votes        0.012615  0.006031 -0.135990  0.206021  0.204080  0.474256
# director     0.015246  0.014656 -0.008553 -0.038354 -0.038668  0.005413
# writer       0.012880 -0.003149  0.017578 -0.025908 -0.027182  0.012843
# star        -0.006882  0.009196  0.003341 -0.032157 -0.032460  0.007296
# country     -0.025490  0.008230 -0.009164 -0.066748 -0.072336 -0.043051
# budget       0.023392 -0.203946 -0.368523  0.327722  0.320207  0.072001
# ...

# %%
correlation_mat=df_numerized.corr()

corr_pairs=correlation_mat.unstack()

corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.029234
#              genre          0.010996
#              year           0.025542
#              released       0.026964
#                               ...
# yearcorrect  budget         0.320312
#              gross          0.268721
#              company       -0.018806
#              runtime        0.075294
#              yearcorrect    1.000000
# Length: 256, dtype: float64

# %%
sorted_pairs=corr_pairs.sort_values()

# %%
sorted_pairs
# Out:
# genre        budget        -0.368523
# budget       genre         -0.368523
# gross        genre         -0.244101
# genre        gross         -0.244101
# rating       budget        -0.203946
#                               ...
# star         star           1.000000
# company      company        1.000000
# gross        gross          1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# Length: 256, dtype: float64

# %%
high_corr=sorted_pairs[(sorted_pairs)>0.5]

high_corr
# Out:
# votes        gross          0.614751
# gross        votes          0.614751
# budget       gross          0.740247
# gross        budget         0.740247
# year         released       0.997618
# released     year           0.997618
# yearcorrect  released       0.998532
# released     yearcorrect    0.998532
# year         yearcorrect    0.998726
# yearcorrect  year           0.998726
# director     director       1.000000
# votes        votes          1.000000
# released     released       1.000000
# score        score          1.000000
# rating       rating         1.000000
# name         name           1.000000
# genre        genre          1.000000
# year         year           1.000000
# budget       budget         1.000000
# country      country        1.000000
# writer       writer         1.000000
# star         star           1.000000
# company      company        1.000000
# gross        gross          1.000000
# runtime      runtime        1.000000
# ...

# %%
## Votes and budgets have the highest correlation to gross earnings
